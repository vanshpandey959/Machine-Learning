# %%
import numpy as np
arr = np.array([2,3,4,6,7,8,9,12,13,16,17,23,25,27,34,37,201])
arr
# Out:
# array([  2,   3,   4,   6,   7,   8,   9,  12,  13,  16,  17,  23,  25,
#         27,  34,  37, 201])

# %%
# Remove outliers
# Find out percentile
Q1 = np.percentile(arr,25)
Q1
Q3 = np.percentile(arr,75)
Q3
# Out:
# np.float64(25.0)

# %%
IQR = Q3-Q1
IQR
# Out:
# np.float64(18.0)

# %%
UpperFence = Q3 + 1.5*(IQR)
LowerFence = Q1 - 1.5*(IQR)

# %%
# We have to remove elements smaller thn lower fence and higher than upperfence as they are outliers

l = []
for i in arr:
    if i >= LowerFence and i <= UpperFence:
        l.append(i)

l # Contains data with no outlier - 201 is removed
arr2 = np.array(l)

# %%
import seaborn as sns
sns.boxplot(x=arr)
# We can see a outlier
# Out:
# <Axes: >

# %%
sns.boxplot(x=arr2)
# Out:
# <Axes: >
