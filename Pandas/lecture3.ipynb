# %%
import numpy as np
import pandas as pd

# %%
data = {
    'Category': ['A', 'B', 'A', 'B', 'A', 'B', 'A', 'B'],
    'Store': ['S1', 'S1', 'S2', 'S2', 'S1', 'S2', 'S2', 'S1'],
    'Sales': [100, 200, 150, 250, 120, 180, 200, 300],
    'Quantity': [10, 15, 12, 18, 8, 20, 15, 25],
    'Date': pd.date_range('2023-01-01', periods=8)
}
df = pd.DataFrame(data)

# %%
df
# Out:
#   Category Store  Sales  Quantity       Date
# 0        A    S1    100        10 2023-01-01
# 1        B    S1    200        15 2023-01-02
# 2        A    S2    150        12 2023-01-03
# 3        B    S2    250        18 2023-01-04
# 4        A    S1    120         8 2023-01-05
# 5        B    S2    180        20 2023-01-06
# 6        A    S2    200        15 2023-01-07
# 7        B    S1    300        25 2023-01-08

# %%
# Grroup by Category and calculate the sum of sales
cat = df.groupby('Category')
for i, v in cat:
    print(i)
    print(v)
# Out:
# A
#   Category Store  Sales  Quantity       Date
# 0        A    S1    100        10 2023-01-01
# 2        A    S2    150        12 2023-01-03
# 4        A    S1    120         8 2023-01-05
# 6        A    S2    200        15 2023-01-07
# B
#   Category Store  Sales  Quantity       Date
# 1        B    S1    200        15 2023-01-02
# 3        B    S2    250        18 2023-01-04
# 5        B    S2    180        20 2023-01-06
# 7        B    S1    300        25 2023-01-08

# %%
sum = df.groupby('Category')['Sales'].sum()
sum
# Out:
# Category
# A    570
# B    930
# Name: Sales, dtype: int64

# %%
# Group by Store 
sum2 = df.groupby('Store')['Sales'].sum()
sum2
# Out:
# Store
# S1    720
# S2    780
# Name: Sales, dtype: int64

# %%
# Qualative - Categorical Data (Male/Female)
sum3 = df.groupby(['Category','Store'])['Sales'].sum()
sum3
# Out:
# Category  Store
# A         S1       220
#           S2       350
# B         S1       500
#           S2       430
# Name: Sales, dtype: int64

# %% [markdown]
# Aggregation

# %%
df['Sales'].mean()
# Out:
# np.float64(187.5)

# %%
df['Sales'].agg(['mean', 'median', 'min', 'max','std'])
# Out:
# mean      187.500000
# median    190.000000
# min       100.000000
# max       300.000000
# std        66.062741
# Name: Sales, dtype: float64

# %% [markdown]
# PIVOT TABLES

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)
df
# Out:
#          Date Product Region  Sales  Units    Rep
# 0  2023-01-01       A   East    266     32   John
# 1  2023-01-02       B   West    636     41   Mary
# 2  2023-01-03       C  North    423     43    Bob
# 3  2023-01-04       D  South    928     52  Alice
# 4  2023-01-05       A   East    827     55   John
# 5  2023-01-06       B   West    350     59   Mary
# 6  2023-01-07       C  North    767     31    Bob
# 7  2023-01-08       D  South    823     77  Alice
# 8  2023-01-09       A   East    483     80   John
# 9  2023-01-10       B   West    486     28   Mary
# 10 2023-01-11       C  North    395     86    Bob
# 11 2023-01-12       D  South    548     68  Alice
# 12 2023-01-13       A   East    685     37   John
# 13 2023-01-14       B   West    481     87   Mary
# 14 2023-01-15       C  North    288     88    Bob
# 15 2023-01-16       D  South    243     22  Alice
# 16 2023-01-17       A   East    250     71   John
# 17 2023-01-18       B   West    541     37   Mary
# 18 2023-01-19       C  North    821     25    Bob
# 19 2023-01-20       D  South    808     22  Alice

# %%
pd.pivot_table(df, values='Sales', index='Region', columns='Product',aggfunc='median')
# Out:
# Product      A      B      C      D
# Region
# East     483.0    NaN    NaN    NaN
# North      NaN    NaN  423.0    NaN
# South      NaN    NaN    NaN  808.0
# West       NaN  486.0    NaN    NaN

# %%
pd.pivot_table(df, values=['Sales','Units'], index='Region', columns='Product',aggfunc='median')
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     483.0    NaN    NaN    NaN  55.0   NaN   NaN   NaN
# North      NaN    NaN  423.0    NaN   NaN   NaN  43.0   NaN
# South      NaN    NaN    NaN  808.0   NaN   NaN   NaN  52.0
# West       NaN  486.0    NaN    NaN   NaN  41.0   NaN   NaN

# %%
pd.crosstab(df['Region'], df['Product'])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0

# %% [markdown]
# OPERATIONS

# %%
df1 = pd.DataFrame({
    'A': [1, 2, 3, 4, 5],
    'B': [10, 20, 30, 40, 50],
    'C': [100, 200, 300, 400, 500]
})
df1
# Out:
#    A   B    C
# 0  1  10  100
# 1  2  20  200
# 2  3  30  300
# 3  4  40  400
# 4  5  50  500

# %%
df1.shape
# Out:
# (5, 3)

# %%
df1.columns
# Out:
# Index(['A', 'B', 'C'], dtype='str')

# %%
df1.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       5 non-null      int64
#  1   B       5 non-null      int64
#  2   C       5 non-null      int64
# dtypes: int64(3)
# memory usage: 252.0 bytes

# %%
df1.describe()
# Out:
#               A          B           C
# count  5.000000   5.000000    5.000000
# mean   3.000000  30.000000  300.000000
# std    1.581139  15.811388  158.113883
# min    1.000000  10.000000  100.000000
# 25%    2.000000  20.000000  200.000000
# 50%    3.000000  30.000000  300.000000
# 75%    4.000000  40.000000  400.000000
# max    5.000000  50.000000  500.000000

# %%
df1['A'] + 10
# not in place
# Out:
# 0    11
# 1    12
# 2    13
# 3    14
# 4    15
# Name: A, dtype: int64

# %%
df1
# Out:
#    A   B    C
# 0  1  10  100
# 1  2  20  200
# 2  3  30  300
# 3  4  40  400
# 4  5  50  500

# %% [markdown]
# DataFrames Applying Functions

# %%
def square(x):
    return x**2
df1['B'].apply(square)
# Out:
# 0     100
# 1     400
# 2     900
# 3    1600
# 4    2500
# Name: B, dtype: int64

# %%
df1['D'] = df1['B'].apply(square)
# df1['D'] = df1['B'].apply(lambda x : x**2)

# %%
df1
# Out:
#    A   B    C     D
# 0  1  10  100   100
# 1  2  20  200   400
# 2  3  30  300   900
# 3  4  40  400  1600
# 4  5  50  500  2500
